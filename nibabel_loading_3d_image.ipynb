# %% [markdown]
# <a href="https://colab.research.google.com/github/s-mostafa-a/visualizing-medical-data/blob/master/nibabel_loading_3d_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nibabel
import nibabel as nib
# !wget https://nipy.org/nibabel/_downloads/c16214e490de2a223655d30f4ba78f15/someones_anatomy.nii.gz
# Out:
# ...
# --2020-06-11 01:06:29--  https://nipy.org/nibabel/_downloads/c16214e490de2a223655d30f4ba78f15/someones_anatomy.nii.gz
# Resolving nipy.org (nipy.org)... 185.199.111.153, 185.199.108.153, 185.199.110.153, ...
# Connecting to nipy.org (nipy.org)|185.199.111.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 191449 (187K) [application/gzip]
# Saving to: ‘someones_anatomy.nii.gz’
#
# someones_anatomy.ni 100%[===================>] 186.96K  --.-KB/s    in 0.03s
#
# 2020-06-11 01:06:29 (6.86 MB/s) - ‘someones_anatomy.nii.gz’ saved [191449/191449]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
def show_slices(slices):
  fig, axes = plt.subplots(1, len(slices))
  for i, slice in enumerate(slices):
    axes[i].imshow(slice.T, cmap="gray", origin="lower")

# %%
anat_img = nib.load('./someones_anatomy.nii.gz')
anat_img_data = anat_img.get_fdata()
show_slices([anat_img_data[28, :, :], anat_img_data[:, 33, :], anat_img_data[:, :, 28]])
anat_img.orthoview()
# Out:
# <OrthoSlicer3D: ./someones_anatomy.nii.gz (57, 67, 56)>
